# %% [markdown]
# <a href="https://colab.research.google.com/github/Docasti/Python-ciencia-datos/blob/main/Copia_de_PRACTICO3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TRABAJO PRACTICO N 3

# %% [markdown]
# ***TEMAS A DESARROLLAR:***
#
# Nociones de Probabilidad, simulación de procesos aleatorios, cálculo de parámetros estadisticos: Media o Valor Esperado(PROMEDIO), Mediana, Desvio Estandar. DISTRIBUCIONES DE PROABABILIDAD más frecuentes, por ejemplo la Normal.

# %% [markdown]
# ## Funciones estadísticas para análisis exploratorio de datos
# A continuación se presentan ejemplos de funciones estadísticas para el análisis exploratorio de datos utilizando NumPy:

# %% [markdown]
# #### Crear array aleatorio
# En esta celda, se utiliza la función np.random.rand() de NumPy para crear un array de números aleatorios con una forma específica. Luego, se imprime el array.

# %%
import numpy as np
random_array = np.random.randint(0,10, (4,3))
print("Array aleatorio:", random_array)
# Out:
# Array aleatorio: [[0 8 5]
#  [0 6 1]
#  [2 6 0]
#  [7 9 2]]

# %% [markdown]
# #### Media
# En esta celda, se crea un array 'array' y se utiliza la función np.mean() de NumPy para calcular la media del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
media = np.mean(array)
print("Media:", media)
# Out:
# Media: 3.0

# %% [markdown]
# #### Desviación estándar
# En esta celda, se crea un array 'array' y se utiliza la función np.std() de NumPy para calcular la desviación estándar del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
desviacion_estandar = np.std(array)
print("Desviación estándar:", desviacion_estandar)
# Out:
# Desviación estándar: 1.4142135623730951

# %% [markdown]
# #### Varianza
# La función np.var() se utiliza para calcular la varianza de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
varianza = np.var(array)
print("Varianza:", varianza)
# Out:
# Varianza: 2.0

# %% [markdown]
# #### Valor mínimo
# En esta celda, se crea un array 'array' y se utiliza la función np.min() de NumPy para encontrar el valor mínimo del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
matriz=np.random.randint(-3,3,(5,5))
#minimo = np.min(array)
minimo = np.min(matriz, axis=0)
print("Valor mínimo:", minimo)
print( matriz)

# %% [markdown]
# #### Valor máximo
# En esta celda, se crea un array 'array' y se utiliza la función np.max() de NumPy para encontrar el valor máximo del array. Luego, se imprime el resultado.

# %%
maximo = np.max(array)
print("Valor máximo:", maximo)
# Out:
# Valor máximo: 5

# %% [markdown]
# #### Gráfico de dispersión
# En esta celda, se crea un array 'x' con valores aleatorios y un array 'y' con valores aleatorios. Luego, se utiliza la biblioteca Matplotlib para trazar un gráfico de dispersión con 'x' en el eje x y 'y' en el eje y. También se agrega etiquetas y un título al gráfico.

# %%
import matplotlib.pyplot as plt
x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de dispersión')
plt.show()

# %% [markdown]
# En esta celda, se crea un array 'data' con valores aleatorios siguiendo una distribución normal. Luego, se utiliza la biblioteca Matplotlib para trazar un histograma de 'data'. También se agrega etiquetas y un título al gráfico.

# %%
import matplotlib.pyplot as plt
data = np.random.normal(0, 1, 1000)

plt.hist(data, bins=30)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma')
plt.show()

# %% [markdown]
# #### Mediana
# La función np.median() se utiliza para calcular la mediana de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
mediana = np.median(array)
print("Mediana:", mediana)
# Out:
# Mediana: 3.0

# %% [markdown]
# #### Percentiles
# La función np.percentile() se utiliza para calcular los percentiles de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
percentil_50 = np.percentile(array, 50)
print("Percentil 50:", percentil_50)
# Out:
# Percentil 50: 3.0

# %% [markdown]
# # EJEMPLOS Y APLICACIÓNES

# %% [markdown]
# ***APLICACIÓN DE PROBABILIDAD***
#
# Se Realiza el lanzamiento de un dado EQUILIBRADO JUSTO, de manera reiterada con las mismas condiciones, y se anotan sus resultados= CARA O CRUZ.
#
# Se le pide al usuario que defina la cantidad N de lanzamientos y se calcula su frecuencia relativa= 'PROBABILIDAD' de obtener cara o cruz. Se obtiene los siguientes resultados:

# %%
import numpy as np
n=int(input('ingrese la cantidad de simulación o lanzamientos'))

#========= FORMA 1 DE SIMULAR LANZAMIENTO DE UN DADO============
dado=[]
cara=0
cruz=0
for i in range(n):
  dado.append(np.random.rand(1))
  dado1=np.array(dado)
  if dado1[i]<0.5:
    #print('salio cara')
    #print(dado[i])
    cara +=1
  else:
    #print('salio cruz')
    #print(dado[i])
    cruz +=1
# Out:
# ingrese la cantidad de simulación o lanzamientos4

# %%
#  mostrar la probailidad frecuencista de el lanzamiento de un dado
prom_cara=cara/n
prom_cruz=cruz/n
print('la probabilidad aproximada en '+str(n)+' lanzamientos de sacar CARA es:', prom_cara)
print('la probabilidad aproximada en '+str(n)+' lanzamientos de sacar CRUZ es:', prom_cruz)
# Out:
# la probabilidad aproximada en 4 lanzamientos de sacar CARA es: 0.5
# la probabilidad aproximada en 4 lanzamientos de sacar CRUZ es: 0.5

# %%
#========== FORMA COMPACTA DE SIMULAR USANDO NUMPY===========
m=int(input('ingrese la cantidad de simulación o lanzamientos'))
lanzamientos = np.random.randint(0, 2, m)

# Calcular las probabilidades

probabilidad_cara = np.sum(lanzamientos ==0 ) / len(lanzamientos)
probabilidad_sello = np.sum(lanzamientos== 1) / len(lanzamientos)

print(f"Probabilidad de cara: {probabilidad_cara:.2f}")
print(f"Probabilidad de sello: {probabilidad_sello:.2f}")
# Out:
# ingrese la cantidad de simulación o lanzamientos6
# Probabilidad de cara: 0.33
# Probabilidad de sello: 0.67

# %%
import matplotlib.pyplot as plt
x=np.array(range(2))
y=np.array([probabilidad_cara, probabilidad_sello])

plt.bar(x,y)
plt.xlabel('Opción')
plt.ylabel('Frecuencia relativa')
plt.title('Histograma del lanzamiento de una moneda equilibrada')
plt.show()

# %% [markdown]
# # EJERCICIOS

# %% [markdown]
# ##***EJERCICIO 1***
#
# Simular el lanzamiento de un dado eqilibrado de 6 caras.
#
#
# *   Mostrar la probabilida aproximada de obtener el número 2, 3 y 5
# *   Graficar el histograma de las probabilidades

# %%
import numpy as np
import matplotlib.pyplot as plt

num_lanzamientos = int(input("Ingrese el número de lanzamientos: "))
resultados = np.random.randint(1, 7, num_lanzamientos)

prob_2 = np.sum(resultados == 2) / num_lanzamientos
prob_3 = np.sum(resultados == 3) / num_lanzamientos
prob_5 = np.sum(resultados == 5) / num_lanzamientos

valores = [2, 3, 5]
probabilidades = [prob_2, prob_3, prob_5]

plt.bar(valores, probabilidades)
plt.xlabel('Número')
plt.ylabel('Probabilidad')
plt.title('Histograma de Probabilidades de Lanzamiento de Dado 6')
plt.xticks(valores)
plt.show()
# Out:
# Ingrese el número de lanzamientos: 9

# %% [markdown]
# ## ***EJERCICIO 2***
#
# Simular el lanzamiento de un dado NO eqilibrado o cargado de 6 caras, de manera que las chances o probabilidades de salir 1 o 2 sean el doble de obtener otro resultado (3,4,5 o 6)
#
#
# *   Mostrar la probabilida aproximada de obtener el número 2, 3 y 5
# *   Graficar el histograma de las probabilidades

# %%
import numpy as np
import matplotlib.pyplot as plt

probabilidades = [0.4, 0.4, 0.1, 0.1]
probabilidades = [p / sum(probabilidades) for p in probabilidades]


num_lanzamientos = int(input("Ingrese el número de lanzamientos: "))

resultados = np.random.choice([1, 2, 3, 4], num_lanzamientos, p=probabilidades)

prob_2 = np.sum(resultados == 2) / num_lanzamientos
prob_3 = np.sum(resultados == 3) / num_lanzamientos
prob_5 = np.sum(resultados == 5) / num_lanzamientos

print(f"Probabilidad de obtener el número 2: {prob_2:.4f}")
print(f"Probabilidad de obtener el número 3: {prob_3:.4f}")
print(f"Probabilidad de obtener el número 5: {prob_5:.4f}")

valores = [2, 3, 5]
probabilidades_resultados = [prob_2, prob_3, prob_5]

plt.bar(valores, probabilidades_resultados)
plt.xlabel('Número')
plt.ylabel('Probabilidad')
plt.title('Histograma de Probabilidades de Lanzamiento de Dado No Equilibrado')
plt.xticks(valores)
plt.show()
# Out:
# Ingrese el número de lanzamientos: 4
# Probabilidad de obtener el número 2: 0.5000
# Probabilidad de obtener el número 3: 0.2500
# Probabilidad de obtener el número 5: 0.0000

# %% [markdown]
# ## EJERCICIO 3
#
#  Realizar la simulación del juego {piedra,papel , tijera} donde el resultado de esta simulación deberá ser lo que mi oponente elije. No debe considerarse la simulación de mi elección.
#
#
#
# *   Calcular la probailidad aproximada que mi oponente elija, 'piedra', 'papel', o 'tijera', en N jugadas.
# *   Realizar un grafico de barra mostrando estas probabilidad. Concluir algo sobre las probabilidades de estos resultados, cuando el número de jugadas se incrementa bastante.

# %%
import numpy as np
import matplotlib.pyplot as plt


opciones = ['piedra', 'papel', 'tijera']

num_jugadas = int(input("Ingrese el número de jugadas: "))

elecciones_oponente = np.random.choice(opciones, num_jugadas)

prob_piedra = np.sum(elecciones_oponente == 'piedra') / num_jugadas
prob_papel = np.sum(elecciones_oponente == 'papel') / num_jugadas
prob_tijera = np.sum(elecciones_oponente == 'tijera') / num_jugadas

print(f"Probabilidad de que el oponente elija 'piedra': {prob_piedra:.4f}")
print(f"Probabilidad de que el oponente elija 'papel': {prob_papel:.4f}")
print(f"Probabilidad de que el oponente elija 'tijera': {prob_tijera:.4f}")


valores = ['piedra', 'papel', 'tijera']
probabilidades_resultados = [prob_piedra, prob_papel, prob_tijera]

plt.bar(valores, probabilidades_resultados)
plt.xlabel('Elección del Oponente')
plt.ylabel('Probabilidad')
plt.title('Probabilidades de Elecciones del Oponente en el Juego de Piedra, Papel o Tijera')
plt.show()
# Out:
# Ingrese el número de jugadas: 7
# Probabilidad de que el oponente elija 'piedra': 0.1429
# Probabilidad de que el oponente elija 'papel': 0.4286
# Probabilidad de que el oponente elija 'tijera': 0.4286

# %% [markdown]
# ## EJERCICIO 4
#
# Dada la base de datos de ventas diarias durante una semana, de un negocio con 4 productos.- VER EJERCICIO PARTE 2 PRACTICO N 2- Realizar el siguiente análisis de datos para poder obtener información y planificar una estrategia de ventas.
#
#
# 1.   Calcular la media en la ventas por cada producto y la mediana. Plotear estos nuevos datos en un gráfico de barra.
# 2.    Calcular la media en la ventas por DÍA y la mediana. Plotear estos nuevos datos en un gráfico de TRAZO DE LINEAS.
# 3.   Realizar una conclusión en función las graficas y sugerir al menos 5 estrategias de venta o inversión de manera de potenciar este negocio.
# 4.   Calcular el desvio estandar de los datos por cada producto y concluir para cada producto como es su rango de variabilidad en las ventas de los mismos.Plotear los datos de ventas de la semana de los productos con mayor y menor desvio estandar y evidenciar la variabilidad indicada en el parametro *'DESVIO ESTANDAR'*

# %%
import matplotlib.pyplot as plt
import pandas as pd

ventas_diarias= np.array(
[[20,	15,	25,	30,	18,	22,	24],
[12,	20,	14,	 8,	15,	18,	16],
[35,	28,	32,	30,	26,	24,	30],
[38,	38,  45,	42,	39,	41,	37]]
)
media_por_producto = np.mean(ventas_diarias, axis=1)
mediana_por_producto = np.median(ventas_diarias, axis=1)

# Plotear los datos de media y mediana
productos = ['Producto 1', 'Producto 2', 'Producto 3', 'Producto 4']
plt.bar(productos, media_por_producto, label='Media', alpha=0.7)
plt.bar(productos, mediana_por_producto, label='Mediana', alpha=0.7)
plt.title('Media y Mediana de Ventas por Producto')
plt.xlabel('Productos')
plt.ylabel('Ventas')
plt.legend()
plt.show()

# media y mediana por día
data['Día'] = pd.to_datetime(data['Día'])
media_dias = data.groupby('Día').mean()
mediana_dias = data.groupby('Día').median()

# Crear un gráfico de líneas para la media y mediana por día
media_dias['Ventas'].plot(kind='line', title='Media por Día')
plt.xlabel('Día')
plt.ylabel('Venta')
plt.legend(title='Estadística')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

mediana_dias['Ventas'].plot(kind='line', title='Mediana por Día')
plt.xlabel('Día')
plt.ylabel('Venta')
plt.legend(title='Estadística')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

#  desvío estándar por producto
desvio_productos = data.groupby('Producto').std()

#  mayor y menor desvío estándar
producto_max_desvio = desvio_productos['Ventas'].idxmax()
producto_min_desvio = desvio_productos['Ventas'].idxmin()

# gráficos con mayor y menor desvío estándar
plt.figure(figsize=(10, 6))
plt.plot(data[data['Producto'] == producto_max_desvio]['Día'], data[data['Producto'] == producto_max_desvio]['Ventas'], marker='o', label=producto_max_desvio)
plt.plot(data[data['Producto'] == producto_min_desvio]['Día'], data[data['Producto'] == producto_min_desvio]['Ventas'], marker='x', label=producto_min_desvio)
plt.xlabel('Día')
plt.ylabel('Venta')
plt.title('Ventas de Productos con Mayor y Menor Desvío Estándar')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-93-39d457364e2e> in <cell line: 24>()
#      22
#      23 # media y mediana por día
# ---> 24 data['Día'] = pd.to_datetime(data['Día'])
#      25 media_dias = data.groupby('Día').mean()
#      26 mediana_dias = data.groupby('Día').median()
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %% [markdown]
# | Producto | Lun | Mar | Mie | Jue | Vie | Sab | Dom | SubTotal |
# |----------|-----|-----|-----|-----|-----|-----|-----|----------|
# | A        | 20  | 15  | 25  | 30  | 18  | 22  | 24  | 154      |
# | B        | 12  | 20  | 14  | 8   | 15  | 18  | 16  | 103      |
# | C        | 35  | 28  | 32  | 30  | 26  | 24  | 30  | 205      |
# | D        | 40  | 38  | 45  | 42  | 39  | 41  | 37  | 282      |
# |----------|-----|-----|-----|-----|-----|-----|-----|----------|
# | Subtotal | 107 | 101 | 116 | **110** | 98  | 105 | 105 | **744**  |
#
# Total de venta semanal: 744 dólares.

# %% [markdown]
# ## EJERCICIO 5
#
# Solicitar al usuario que ingrese la cantidad N de datos a cargar. Luego generar de manera aleatoria los siguientes datos:
#
# * SEXO= 'MASCULINO', 'FEMENINO','NO ESPECIFICA'
# * EDAD= entre 28 y 60 años
# * ALTURA= entre un rango de 165.0 mts hasta 210 mts
# * PESO= entre un rango de 50  y 110 kg
# * HORAS DE DESCANSO diario= un número decimal
# * HORAS DE TRABAJO/ ESTUDIO diario= un número decimal
# * HORAS DE EJERCICIOS diario= un número decimal
#
# REalizar las siguientes indicaciones y extraer concluisiones sobre la información y la pooblación muestreada.
#
# 1.   Generar un array de dimensión 2 (matriz), con todos los datos ordenados, permitiendo visualizarlos como tabla.
# 2.   Suponiendo que la distribución de probabilidad de los datos muestrados de las N personas, se distribuyen en forma NORMAL. Encontrar la media en los datos de altura, peso, y horas de descanso, trabajo y ejercicios.
# 3.  Graficar la muestra o distribución de los datos  de pesos , y alturas en graficas separadas. Indicar el grado de variabilidad de sus datos
# 4.  Plotear de manera conjunta y encontrar si presentan correlación los datos de peso vs altura,
# 5. Plotear de manera conjunta los datos de horas de descanso, estudio y ejercicio

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

def generar_datos(cantidad):
    sexos = ['MASCULINO', 'FEMENINO', 'NO ESPECIFICA']
    edades = np.random.randint(28, 61, size=cantidad)
    alturas = np.random.uniform(165.0, 210.0, size=cantidad).round(2)
    pesos = np.random.randint(50, 111, size=cantidad)
    horas_descanso = np.random.uniform(4.0, 9.0, size=cantidad).round(1)
    horas_trabajo_estudio = np.random.uniform(4.0, 12.0, size=cantidad).round(1)
    horas_ejercicio = np.random.uniform(0.0, 2.0, size=cantidad).round(1)

    datos = []
    for _ in range(cantidad):
        sexo = np.random.choice(sexos)
        edad = np.random.choice(edades)
        altura = np.random.choice(alturas)
        peso = np.random.choice(pesos)
        descanso = np.random.choice(horas_descanso)
        trabajo_estudio = np.random.choice(horas_trabajo_estudio)
        ejercicio = np.random.choice(horas_ejercicio)
        datos.append((sexo, edad, altura, peso, descanso, trabajo_estudio, ejercicio))

    return datos

cantidad_datos = int(input("Ingrese la cantidad de datos a cargar: "))

datos_generados = generar_datos(cantidad_datos)

for dato in datos_generados:
    print(dato)
#1
datos = np.array([
    ['MASCULINO', 32, 175.5, 80, 7.5, 8.0, 1.5],
    ['FEMENINO', 42, 190.0, 65, 6.8, 6.5, 0.5],
    ['NO ESPECIFICA', 50, 200.5, 95, 8.2, 10.0, 1.2],

])
#2
columnas = ['Sexo', 'Edad', 'Altura', 'Peso', 'Horas Descanso', 'Horas Trabajo/Estudio', 'Horas Ejercicio']
df = pd.DataFrame(data=datos, columns=columnas)


df[columnas[1:]] = df[columnas[1:]].apply(pd.to_numeric)

media_altura = df['Altura'].mean()
media_peso = df['Peso'].mean()
media_descanso = df['Horas Descanso'].mean()
media_trabajo_estudio = df['Horas Trabajo/Estudio'].mean()
media_ejercicio = df['Horas Ejercicio'].mean()

#3
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(df['Peso'], bins=10, edgecolor='black')
plt.title('Distribución de Pesos')
plt.xlabel('Peso')
plt.ylabel('Frecuencia')

plt.subplot(1, 2, 2)
plt.hist(df['Altura'], bins=10, edgecolor='black')
plt.title('Distribución de Alturas')
plt.xlabel('Altura')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()


plt.scatter(df['Peso'], df['Altura'])
plt.title('Correlación entre Peso y Altura')
plt.xlabel('Peso')
plt.ylabel('Altura')
plt.grid(True)
plt.show()

plt.plot(df['Horas Descanso'], label='Descanso')
plt.plot(df['Horas Trabajo/Estudio'], label='Trabajo/Estudio')
plt.plot(df['Horas Ejercicio'], label='Ejercicio')
plt.title('Horas de Descanso, Trabajo/Estudio y Ejercicio')
plt.xlabel('Persona')
plt.ylabel('Horas')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Ingrese la cantidad de datos a cargar: 130
# ('NO ESPECIFICA', 34, 174.12, 56, 6.9, 10.4, 1.8)
# ('FEMENINO', 29, 192.28, 75, 4.5, 11.4, 1.1)
# ('NO ESPECIFICA', 50, 182.11, 69, 6.9, 8.8, 0.4)
# ('NO ESPECIFICA', 30, 200.19, 72, 5.1, 7.7, 1.6)
# ('MASCULINO', 29, 207.26, 52, 8.8, 10.3, 0.1)
# ('MASCULINO', 50, 179.84, 63, 7.5, 5.7, 0.4)
# ('FEMENINO', 29, 200.19, 97, 8.8, 11.7, 0.2)
# ('MASCULINO', 28, 198.62, 75, 5.3, 5.6, 1.2)
# ('FEMENINO', 37, 206.74, 109, 8.2, 5.2, 0.3)
# ('FEMENINO', 28, 183.63, 71, 6.4, 5.1, 1.6)
# ('FEMENINO', 52, 205.93, 97, 8.2, 5.7, 1.7)
# ('MASCULINO', 28, 187.05, 95, 7.8, 10.6, 0.1)
# ('NO ESPECIFICA', 41, 200.27, 109, 6.5, 6.7, 1.2)
# ('MASCULINO', 48, 207.4, 100, 7.0, 11.4, 0.3)
# ('FEMENINO', 33, 184.43, 90, 8.2, 5.5, 1.0)
# ('NO ESPECIFICA', 57, 174.95, 74, 8.5, 8.1, 0.1)
# ('MASCULINO', 30, 184.43, 94, 7.8, 4.6, 0.8)
# ('NO ESPECIFICA', 34, 174.62, 75, 7.2, 7.0, 1.3)
# ('NO ESPECIFICA', 51, 180.43, 75, 8.4, 5.1, 1.6)
# ...

# %% [markdown]
# ## EJERCICIO 6
#
# Se realiza una encuesta a N usuario donde se registran los siguientes datos.
#
# ['DNI','GASTOS MENSUALES DE HOGAR','INGRESOS MENSUALES POR HOGAR', 'CANTIDAD DE MIEMBROS QUE VIVEN POR HOGAR','GASTO MENSUAL EN LINEA TELEFÓNICA', 'GASTO MENSUAL POR PAGO DE INTERNET' ]
#
# Realizar la simulación de la carga de datos utilizando la siguiente información adicional:
#
#
# 1.   El 70 % de los encuestados son jóvenes entre 15 y 21 años, el 10% son mayores de 60 años. Sugerencia, utilizar esto para generar los DNI
# 2.   Los encuestados son de la provincia de Cordoba. Además el 80 % de la población de esa provincia tiene un grupo familiar de 5 personas. Con ingresos mensuales promedio de $258.000
# 2.   Cerca del 80 % de los encuestados Gastan el 90% de sus ingresos, el resto gasta el 80% de sus ingresos.Ayuda, para simular la cantidad de miembros utilizar la distribución normal.
# 3.  Del gasto Total por hogar se sabe que se abona un 15 % en telefonía y un 7.8% en servicio de internet.
#
# Con la información proporcionada, realizar la simulación de las encuestas de 100 y 1000 personas.
#
# *   Calcular el valor medio y desvio estandar de los gastos mensuales, ingresos mensuales y pagos de servicios.
# *   Plotear los datos de los ingesos , y gastos en gráficos de barra por separado y evidenciar la media y desvio estandar.
# *   Calcular la proporciona de jóvenes menores a 21 encuestados. Mostrar sus datos de grupos familiares, gastos en servicios de internet y telefonía. Concluir algo en base a esta información.
# *   Realizar un histograma con el dato del grupo familiar, y concluir algo acerca de la distribución de probabilidad.

# %%
import numpy as np
import matplotlib.pyplot as plt
# Simulación de encuestas
def simular_encuesta(cantidad):
    edades = np.random.choice(['15-21', '22-59', '60+'], size=cantidad, p=[0.7, 0.2, 0.1])

    media_miembros = 5
    desvio_miembros = 1.2
    # Simulación de encuestas
def simular_encuesta(cantidad):
    edades = np.random.choice(['15-21', '22-59', '60+'], size=cantidad, p=[0.7, 0.2, 0.1])

    media_miembros = 5
    desvio_miembros = 1.2
    miembros_hogar = np.round(np.random.normal(media_miembros, desvio_miembros, size=cantidad))
    miembros_hogar = np.clip(miembros_hogar, 1, None)

    ingresos_promedio = 258000
    ingresos_mensuales = np.round(np.random.uniform(0.8, 1.0, size=cantidad) * ingresos_promedio, 2)

    gasto_total = np.where(np.random.rand(cantidad) < 0.8, ingresos_mensuales * 0.9, ingresos_mensuales * 0.8)

    gasto_telefonia = gasto_total * 0.15
    gasto_internet = gasto_total * 0.078

    datos = pd.DataFrame({
        'DNI': [str(np.random.randint(10000000, 100000000)) for _ in range(cantidad)],
        'Edad': edades,
        'Miembros Hogar': miembros_hogar,
        'Ingresos Mensuales': ingresos_mensuales,
        'Gasto Total': gasto_total,
        'Gasto Telefonía': gasto_telefonia,
        'Gasto Internet': gasto_internet
    })

    return datos

# Simular encuestas para 100 y 1000 personas
encuestas_100 = simular_encuesta(100)
encuestas_1000 = simular_encuesta(1000)

media_gastos_mensuales = np.mean(encuestas_100['Gasto Total'])
desvio_gastos_mensuales = np.std(encuestas_100['Gasto Total'])

media_ingresos_mensuales = np.mean(encuestas_100['Ingresos Mensuales'])
desvio_ingresos_mensuales = np.std(encuestas_100['Ingresos Mensuales'])

media_pagos_servicios = np.mean(encuestas_100[['Gasto Telefonía', 'Gasto Internet']].sum(axis=1))
desvio_pagos_servicios = np.std(encuestas_100[['Gasto Telefonía', 'Gasto Internet']].sum(axis=1))

# Plotear los datos de ingresos y gastos en gráficos de barra
categorias = ['Ingresos Mensuales', 'Gasto Total', 'Pagos Servicios']
valores_medios = [media_ingresos_mensuales, media_gastos_mensuales, media_pagos_servicios]
desvios_estandar = [desvio_ingresos_mensuales, desvio_gastos_mensuales, desvio_pagos_servicios]

plt.bar(categorias, valores_medios, yerr=desvios_estandar, alpha=0.7)
plt.title('Comparación de Ingresos y Gastos')
plt.ylabel('Monto')
plt.xticks(rotation=45)
plt.show()

# Calcular la proporción de jóvenes menores a 21 encuestados
proporcion_jovenes = len(encuestas_100[encuestas_100['Edad'] == '15-21']) / len(encuestas_100) * 100

# Mostrar datos de grupos familiares, gastos en servicios de internet y telefonía para jóvenes
datos_jovenes = encuestas_100[encuestas_100['Edad'] == '15-21']
media_grupo_familiar_jovenes = np.mean(datos_jovenes['Miembros Hogar'])
media_gasto_internet_jovenes = np.mean(datos_jovenes['Gasto Internet'])
media_gasto_telefonia_jovenes = np.mean(datos_jovenes['Gasto Telefonía'])

# Imprimir conclusiones y sugerencias
print(f"Proporción de jóvenes menores a 21 años: {proporcion_jovenes:.2f}%")
print(f"Media de miembros en grupo familiar de jóvenes: {media_grupo_familiar_jovenes:.2f}")
print(f"Media de gasto en internet de jóvenes: {media_gasto_internet_jovenes:.2f}")
print(f"Media de gasto en telefonía de jóvenes: {media_gasto_telefonia_jovenes:.2f}")

print("\nSugerencias de estrategias de venta o inversión:")
print("1. Ofrecer planes de telefonía e internet atractivos para jóvenes.")
print("2. Lanzar promociones dirigidas a familias con mayor cantidad de miembros.")
print("3. Realizar campañas publicitarias enfocadas en reducir el gasto en servicios.")
print("4. Diseñar productos o servicios acorde al perfil de gasto de los encuestados.")
print("5. Ofrecer descuentos por la compra de productos en grupo familiar.")

# Calcular y plotear histograma del dato del grupo familiar
plt.hist(encuestas_100['Miembros Hogar'], bins=10, alpha=0.7)
# Out:
# Proporción de jóvenes menores a 21 años: 68.00%
# Media de miembros en grupo familiar de jóvenes: 4.84
# Media de gasto en internet de jóvenes: 15986.80
# Media de gasto en telefonía de jóvenes: 30743.85
#
# Sugerencias de estrategias de venta o inversión:
# 1. Ofrecer planes de telefonía e internet atractivos para jóvenes.
# 2. Lanzar promociones dirigidas a familias con mayor cantidad de miembros.
# 3. Realizar campañas publicitarias enfocadas en reducir el gasto en servicios.
# 4. Diseñar productos o servicios acorde al perfil de gasto de los encuestados.
# 5. Ofrecer descuentos por la compra de productos en grupo familiar.
# (array([ 1.,  0., 17.,  0., 21.,  0., 29.,  0., 28.,  4.]),
#  array([2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. ]),
#  <BarContainer object of 10 artists>)
