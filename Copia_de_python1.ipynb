# %% [markdown]
# <a href="https://colab.research.google.com/github/Docasti/Python-ciencia-datos/blob/main/Copia_de_python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# texto en colab

# %%
# comentario en colab
print( "Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# otro texto en colab

# %%
"""
comentario
con saltos
de lineas
"""

print(" comentario en codigo python")
# Out:
#  comentario en codigo python

# %% [markdown]
# mi foto en texto

# %% [markdown]
# ![do.png](data:image/png;base64,...)
